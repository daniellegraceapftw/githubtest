# %% [markdown]
# <a href="https://colab.research.google.com/github/daniellegraceapftw/githubtest/blob/main/Dataviz_with_Python_FTW.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Import Datasets

# %% [markdown]
# We are going to us the [Iris](https://archive.ics.uci.edu/ml/datasets/iris) and the [Wine Reviews](https://www.kaggle.com/zynicide/wine-reviews) dataset.

# %%
# %matplotlib inline  #making sure matplotlib is inline
import pandas as pd
import numpy as np
# Out:
# UsageError: unrecognized arguments: #making sure matplotlib is inline

# %%
iris = pd.read_csv('iris.csv', names=['sepal_length', 'sepal_width', 'petal_length', 'petal_width', 'class'])
iris.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width        class
# 0           5.1          3.5           1.4          0.2  Iris-setosa
# 1           4.9          3.0           1.4          0.2  Iris-setosa
# 2           4.7          3.2           1.3          0.2  Iris-setosa
# 3           4.6          3.1           1.5          0.2  Iris-setosa
# 4           5.0          3.6           1.4          0.2  Iris-setosa

# %%
wine_reviews = pd.read_csv('winemag-data-130k-v2.csv', index_col=0)
wine_reviews.head(1)
# Out:
#   country                                        description   designation  \
# 0   Italy  Aromas include tropical fruit, broom, brimston...  Vulkà Bianco
#
#    points  price           province region_1 region_2    taster_name  \
# 0      87    NaN  Sicily & Sardinia     Etna      NaN  Kerin O’Keefe
#
#   taster_twitter_handle                              title      variety  \
# 0          @kerinokeefe  Nicosia 2013 Vulkà Bianco  (Etna)  White Blend
#
#     winery
# 0  Nicosia

# %% [markdown]
# ## Matplotlib

# %% [markdown]
# Matplotlib is a Python plotting libary.

# %%
import matplotlib.pyplot as plt

# %% [markdown]
# ### Scatter plot

# %%
# create a figure and axis
fig, ax = plt.subplots()

# scatter the sepal_length against the sepal_width
ax.scatter(iris['sepal_length'], iris['sepal_width'])
# set a title and labels
ax.set_title('Iris Dataset')
ax.set_xlabel('sepal_length')
ax.set_ylabel('sepal_width')
# Out:
# Text(0, 0.5, 'sepal_width')

# %% [markdown]
# We can color each point by class

# %%
colors = {'Iris-setosa':'r', 'Iris-versicolor':'g', 'Iris-virginica':'b'}
fig, ax = plt.subplots()
for i in range(len(iris['sepal_length'])):
    ax.scatter(iris['sepal_length'][i], iris['sepal_width'][i],color=colors[iris['class'][i]])
ax.set_title('Iris Dataset')
ax.set_xlabel('sepal_length')
ax.set_ylabel('sepal_width')
# Out:
# Text(0, 0.5, 'sepal_width')

# %% [markdown]
# #### *Tweak*

# %%
from matplotlib import rcParams, cycler
#rcParams for design and cycler for color

# %%
#Changing the Size
colors = {'Iris-setosa':'r', 'Iris-versicolor':'g', 'Iris-virginica':'b'}

rcParams['figure.figsize'] = 9,7

fig, ax = plt.subplots()
for i in range(len(iris['sepal_length'])):
    ax.scatter(iris['sepal_length'][i], iris['sepal_width'][i],color=colors[iris['class'][i]])
ax.set_title('Iris Dataset')
ax.set_xlabel('sepal_length')
ax.set_ylabel('sepal_width')
# Out:
# Text(0, 0.5, 'sepal_width')

# %%
#Removing the Borders 
colors = {'Iris-setosa':'r', 'Iris-versicolor':'g', 'Iris-virginica':'b'}

#to remove top and right borders
rcParams['axes.spines.top'] = False
rcParams['axes.spines.right'] = False

fig, ax = plt.subplots()
for i in range(len(iris['sepal_length'])):
    ax.scatter(iris['sepal_length'][i], iris['sepal_width'][i],color=colors[iris['class'][i]])
ax.set_title('Iris Dataset')
ax.set_xlabel('sepal_length')
ax.set_ylabel('sepal_width')
# Out:
# Text(0, 0.5, 'sepal_width')

# %% [markdown]
# ### Line Chart

# %%
iris.shape[0]
# Out:
# 150

# %%
iris
# Out:
#      sepal_length  sepal_width  petal_length  petal_width           class
# 0             5.1          3.5           1.4          0.2     Iris-setosa
# 1             4.9          3.0           1.4          0.2     Iris-setosa
# 2             4.7          3.2           1.3          0.2     Iris-setosa
# 3             4.6          3.1           1.5          0.2     Iris-setosa
# 4             5.0          3.6           1.4          0.2     Iris-setosa
# ..            ...          ...           ...          ...             ...
# 145           6.7          3.0           5.2          2.3  Iris-virginica
# 146           6.3          2.5           5.0          1.9  Iris-virginica
# 147           6.5          3.0           5.2          2.0  Iris-virginica
# 148           6.2          3.4           5.4          2.3  Iris-virginica
# 149           5.9          3.0           5.1          1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %%
#remove the 'class' columnn
columns = iris.columns.drop(['class'])

fig, ax = plt.subplots()
for column in columns:
    ax.plot(iris[column])
ax.set_title('Iris Dataset')
ax.legend(iris[columns])

# %%
columns = iris.columns.drop(['class'])

rcParams['lines.linewidth'] = 4
rcParams['axes.prop_cycle'] = cycler(color=['#d98082'])

fig, ax = plt.subplots()
for column in columns:
    ax.plot(iris[column])
ax.set_title('Iris Dataset')
ax.legend(iris[columns])

# %% [markdown]
# ### <font color='red'> Challenge 1
#
#
# Using the chart above, highlight the sepal width

# %%
columns = iris.columns.drop(['class'])

rcParams['lines.linewidth'] = 4
rcParams['axes.prop_cycle'] = cycler(color=['gray'])

fig, ax = plt.subplots()
for column in columns:
    ax.plot(iris[column])
ax.set_title('Iris Dataset')
ax.legend(iris[columns])
iris['sepal_width'].plot(color=['purple'])

# %% [markdown]
# ### <font color='red'> Challenge 2
#
#
# Reset the RCParams

# %%
columns = iris.columns.drop(['class'])

rcParams['lines.linewidth'] = 1
rcParams['axes.prop_cycle'] = cycler(color=['gray'])

fig, ax = plt.subplots()
for column in columns:
    ax.plot(iris[column])
ax.set_title('Iris Dataset')
ax.legend(iris[columns])
iris['sepal_width'].plot(color=['purple'])

# %% [markdown]
# ### Histogram

# %%
fig, ax = plt.subplots()
ax.hist(wine_reviews['points'])
ax.set_title('Wine Review Scores')
ax.set_xlabel('Points')
ax.set_ylabel('Frequency')
# Out:
# Text(0, 0.5, 'Frequency')

# %%
#Tweaking the Tick Size 

rcParams['xtick.labelsize'] = 'xx-large'
rcParams['ytick.labelsize'] = 'xx-large'

fig, ax = plt.subplots()
ax.hist(wine_reviews['points'])
ax.set_title('Wine Review Scores')
ax.set_xlabel('Points')
ax.set_ylabel('Frequency')
# Out:
# Text(0, 0.5, 'Frequency')

# %% [markdown]
# ### <font color='red'> Challenge 3
#
#
# Using the chart above, increase the legend font to appear as large as the tick marks

# %%
#Tweaking the Tick Size 

rcParams['xtick.labelsize'] = 'xx-large'
rcParams['ytick.labelsize'] = 'xx-large'

fig, ax = plt.subplots()
ax.hist(wine_reviews['points'])
ax.set_title('Wine Review Scores')
ax.set_xlabel('Points', size='xx-large')
ax.set_ylabel('Frequency', size='xx-large')
# Out:
# Text(0, 0.5, 'Frequency')

# %% [markdown]
# ### Bar Chart

# %%
fig, ax = plt.subplots()
data = wine_reviews['points'].value_counts()
points = data.index
frequency = data.values
ax.bar(points, frequency)
ax.set_title('Wine Review Scores')
ax.set_xlabel('Points')
ax.set_ylabel('Frequency')
# Out:
# Text(0, 0.5, 'Frequency')

# %% [markdown]
# ## Pandas Visualization

# %% [markdown]
# Pandas uses Matplotlib and makes it easy to plot Data

# %% [markdown]
# ### Scatter Plot

# %%
iris.plot.scatter(x='sepal_length', y='sepal_width', title='Iris Dataset')

# %% [markdown]
# ### Line Chart

# %%
iris.drop(['class'], axis=1).plot.line(title='Iris Dataset')

# %% [markdown]
# ### Histogram

# %%
wine_reviews['points'].plot.hist(title='Wine Review Scores')

# %%
iris.plot.hist(subplots=True, layout=(2,2), figsize=(8, 8), bins=20)
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f39dcdaf520>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f39dcd53850>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7f39dcd72a90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f39dcd20bb0>]],
#       dtype=object)

# %% [markdown]
# ### Bar Chart

# %%
wine_reviews['points'].value_counts().sort_index().plot.bar()

# %%
wine_reviews['points'].value_counts().sort_index().plot.barh()

# %%
wine_reviews.groupby("country").price.mean().sort_values(ascending=False)[:5].plot.bar()

# %% [markdown]
# ## Seaborn

# %% [markdown]
# Seaborn is a Python data visualization library based on matplotlib. It provides a high-level interface for drawing attractive and informative statistical graphics.

# %% [markdown]
# ### Scatter plot

# %%
import seaborn as sns
sns.__version__
# Out:
# '0.11.2'

# %%
sns.scatterplot(x='sepal_length', y='sepal_width', data=iris)

# %% [markdown]
# Highlighting the classes is significally easier than using Matplotlib. We only need to specify the hue parameter.

# %%
rcParams['figure.figsize'] = 8,7
sns.scatterplot(x='sepal_length', y='sepal_width', hue='class', data=iris)

# %% [markdown]
# ### Line chart

# %%
sns.lineplot(data=iris.drop(['class'], axis=1))

# %% [markdown]
# ### Histogram

# %%
sns.distplot(wine_reviews['points'], bins=10, kde=False)
# Out:
# /usr/local/lib/python3.8/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
sns.distplot(wine_reviews['points'], bins=10, kde=True)

# %% [markdown]
# ### Bar chart

# %%
sns.countplot(wine_reviews['points'])
# Out:
# /usr/local/lib/python3.8/dist-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
fig=sns.jointplot(x='sepal_length', y='sepal_width',data=iris)

# %%
sns.jointplot(x='sepal_length', y='sepal_width', data=iris, kind="reg")
pass

# %%
fig=sns.jointplot(x='sepal_length', y='sepal_width',kind='hex',data=iris)

# %%
sns.jointplot(x='sepal_length', y='sepal_width', data=iris, kind="kde",space=0,color='g')
pass
g = (sns.jointplot(x='sepal_length', y='sepal_width',data=iris, color="k").plot_joint(sns.kdeplot, zorder=0, n_levels=6))

# %% [markdown]
# ### Box Plots

# %% [markdown]
# Box Plots are useful to show distributions with respect to categories.

# %%
df = wine_reviews[(wine_reviews['points']>=95) & (wine_reviews['price']<1000)]
sns.boxplot('points', 'price', data=df)
# Out:
# /usr/local/lib/python3.8/dist-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# ### Pie Plots

# %%
wine_reviews.groupby("country").price.mean().sort_values(ascending=False)[:5].plot.pie()

# %% [markdown]
# ### Heatmap

# %% [markdown]
# Heatmaps are perfect for exploring the correlation of the features

# %%
corr = iris.corr()
fig, ax = plt.subplots()
im = ax.imshow(corr.values)

# %%
# get correlation matrix
corr = iris.corr()
fig, ax = plt.subplots()
# create heatmap
im = ax.imshow(corr.values)

# set labels
ax.set_xticks(np.arange(len(corr.columns)))
ax.set_yticks(np.arange(len(corr.columns)))
ax.set_xticklabels(corr.columns)
ax.set_yticklabels(corr.columns)

# Rotate the tick labels and set their alignment.
plt.setp(ax.get_xticklabels(), rotation=45, ha="right",
         rotation_mode="anchor")
# Out:
# [None, None, None, None, None, None, None, None]

# %%
# get correlation matrix
corr = iris.corr()
fig, ax = plt.subplots()
# create heatmap
im = ax.imshow(corr.values)

# set labels
ax.set_xticks(np.arange(len(corr.columns)))
ax.set_yticks(np.arange(len(corr.columns)))
ax.set_xticklabels(corr.columns)
ax.set_yticklabels(corr.columns)

# Rotate the tick labels and set their alignment.
plt.setp(ax.get_xticklabels(), rotation=45, ha="right",
         rotation_mode="anchor")

# Loop over data dimensions and create text annotations.
for i in range(len(corr.columns)):
    for j in range(len(corr.columns)):
        text = ax.text(j, i, np.around(corr.iloc[i, j], decimals=2),
                       ha="center", va="center", color="black")

# %%
sns.heatmap(iris.corr(), annot=True)

# %% [markdown]
# We can make plots bigger by using the figsize parameter from matplotlib. To use it with Seaborn we need to pass the seaborn function we are using the matplotlib axis as an argument.

# %%
fig, ax = plt.subplots(figsize=(10,10))
sns.heatmap(iris.corr(), annot=True, ax=ax)

# %% [markdown]
# ## Faceting

# %% [markdown]
# Faceting is the act of breaking data variables up across multiple subplots, and combining those subplots into a single figure.

# %% [markdown]
# ### FacetGrid

# %%
g = sns.FacetGrid(iris, col='class')
g = g.map(sns.kdeplot, 'sepal_length')

# %% [markdown]
# ### Pairplot

# %%
sns.pairplot(iris)

# %%
from pandas.plotting import scatter_matrix

fig, ax = plt.subplots(figsize=(12,12))
scatter_matrix(iris, alpha=1, ax=ax);
# Out:
# <ipython-input-132-7ee28506892f>:4: UserWarning: To output multiple subplots, the figure containing the passed axes is being cleared
#   scatter_matrix(iris, alpha=1, ax=ax);

# %% [markdown]
# ### <font color = 'Green'> HANDS ON ACTIVITY

# %% [markdown]
# 1. Go to https://tinyurl.com/4avyks4z
# 2. Clean the data if necessary
# 3. Execute all the procedures above using the dataset
# 4. Generate atleast 3 valuable insights
# 5. Up for the challenge? answer the **challenges** to get extra points and do charts such as the following: <br>
#     a. violin plot <br>
#     b. swarm plot <br>
#     c. factor plot <br>
#     d. strip plot
